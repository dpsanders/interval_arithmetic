# %%
import numpy as np
from sympy.mpmath import mp, mpf

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
xx = np.linspace( -2.5*np.pi, 2.5*np.pi, 1000)
plt.plot(xx,np.sin(xx))
plt.plot(xx,np.cos(xx))

x0 = -2*np.pi-0.3
y0 = -0.5
puntos = [ x0, y0 ]
plt.plot(puntos,np.sin(puntos),'o')
plt.plot(puntos,np.cos(puntos),'o')

# %%
from intervalo import *

# %%
pi = np.pi
afijo = 0
q1 = 3
q2 = 1
if q1 > q2 : q2 = q2+4
alow = q1*pi/2. #+ 0.3
ahig = q2*pi/2. + 0.2

xx = np.linspace( alow -2.5*np.pi, ahig + 2.5*np.pi, 1000)
plt.plot(xx,np.sin(xx))
plt.plot(xx,np.cos(xx))
puntos = [ alow, ahig ]
plt.plot(alow,np.sin(alow),'ro')
plt.plot(ahig,np.sin(ahig),'go')
plt.plot(alow,np.cos(alow),'ro')
plt.plot(ahig,np.cos(ahig),'go')

print alow, ahig
print "sin : ", sin( Intervalo(alow,ahig) )
print "cos : ", cos( Intervalo(alow,ahig) )
# Out:
# 4.71238898038 8.05398163397
# sin :  [-1.0,1.0]
# cos :  [-0.198669330790668,1.0]

# %%
pi = np.pi
pi_half = pi/2.
dospi = 2.*pi
x_list = []
sin_list = []
cos_list = []
for i in range(11):
    q1 = np.random.randint(0,4)
    q2 = np.random.randint(0,4)
    print "ii= ", i, " : ", q1, q2
    if q1 > q2 :
        q2 = q2+4
    
    alow = q1*pi_half + np.random.uniform(0,pi_half)
    ahig = q2*pi_half + np.random.uniform(0,pi_half)
    
    x = Intervalo(alow,ahig)
    ys = sin(x)
    yc = cos(x)
    x_list.append((alow,ahig))
    sin_list.append(ys)
    cos_list.append(yc)
    print " x = ", x
    print "sin( x ) = ", ys
    print "cos( x ) = ", yc
    print
# Out:
# ii=  0  :  2 1
#  x =  [4.15083396233,8.53003446194]
# sin( x ) =  [-1.0,1.0]
# cos( x ) =  [-0.625718920354217,1.0]
#
# ii=  1  :  3 1
#  x =  [5.64496663662,8.27562369256]
# sin( x ) =  [-0.595765697839968,1.0]
# cos( x ) =  [-0.409259248185926,1.0]
#
# ii=  2  :  3 3
#  x =  [5.01443628116,5.0276746529]
# sin( x ) =  [-0.954729468682729,-0.950707834067968]
# cos( x ) =  [0.297475447102436,0.310088074975148]
#
# ii=  3  :  3 0
#  x =  [5.6968114252,6.74828144178]
# sin( x ) =  [-0.553344282828493,0.448508726552422]
# cos( x ) =  [0.832952642507976,1.0]
#
# ii=  4  :  0 0
#  x =  [0.378255426027,0.532817547134]
# sin( x ) =  [0.369299781626736,0.507962330972079]
# cos( x ) =  [0.86137928365698,0.9293103202324]
#
# ii=  5  :  2 1
#  x =  [3.4374072985,8.41570368829]
# sin( x ) =  [-1.0,1.0]
# cos( x ) =  [-0.956564975119016,1.0]
#
# ii=  6  :  2 0
#  x =  [3.93861313505,6.40826438033]
# sin( x ) =  [-1.0,0.124753189190759]
# cos( x ) =  [-0.698840989441876,1.0]
#
# ii=  7  :  1 1
#  x =  [2.01653046014,2.33768540273]
# sin( x ) =  [0.720072816071556,0.902294408709131]
# cos( x ) =  [-0.693898508108195,-0.431120400830488]
#
# ii=  8  :  3 2
#  x =  [5.11195234677,10.1828501054]
# sin( x ) =  [-0.921230939336274,1.0]
# cos( x ) =  [-1.0,1.0]
#
# ii=  9  :  0 0
#  x =  [0.321801995553,1.11306508218]
# sin( x ) =  [0.316276566964286,0.897057400217283]
# cos( x ) =  [0.44191404222474,0.948667029673365]
#
# ii=  10  :  3 0
#  x =  [5.89694593706,7.08826993543]
# sin( x ) =  [-0.376707494301204,0.720889297208917]
# cos( x ) =  [0.693050229903745,1.0]

# %%
ii = 10
alow, ahig = x_list[ii]

xx = np.linspace( alow -1.5*pi, ahig + 1.5*pi, 1000)
plt.plot(xx,np.sin(xx))
plt.plot(xx,np.cos(xx))
plt.plot(alow,np.sin(alow),'ro')
plt.plot(ahig,np.sin(ahig),'go')
plt.plot(alow,np.cos(alow),'ro')
plt.plot(ahig,np.cos(ahig),'go')

print alow, ahig
print mp.floor( (alow%dospi)/pi_half ), mp.floor( (ahig%dospi)/pi_half )
print "sin:", sin(Intervalo(alow,ahig) )
print "cos:", cos(Intervalo(alow,ahig) )
# Out:
# 5.89694593706 7.08826993543
# 3.0 0.0
# sin: [-0.376707494301204,0.720889297208917]
# cos: [0.693050229903745,1.0]
