# %%
import numpy as np
from sympy.mpmath import mp, mpf

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
xx = np.linspace( -2.5*np.pi, 2.5*np.pi, 1000)
plt.plot(xx,np.sin(xx))
plt.plot(xx,np.cos(xx))

x0 = -2*np.pi-0.3
y0 = -0.5
puntos = [ x0, y0 ]
plt.plot(puntos,np.sin(puntos),'o')
plt.plot(puntos,np.cos(puntos),'o')

# %%
from intervalo import *

# %%
pi = np.pi
afijo = 0
q1 = 3
q2 = 1
if q1 > q2 : q2 = q2+4
alow = q1*pi/2. #+ 0.3
ahig = q2*pi/2. + 0.2

xx = np.linspace( alow -2.5*np.pi, ahig + 2.5*np.pi, 1000)
plt.plot(xx,np.sin(xx))
plt.plot(xx,np.cos(xx))
puntos = [ alow, ahig ]
plt.plot(alow,np.sin(alow),'ro')
plt.plot(ahig,np.sin(ahig),'go')
plt.plot(alow,np.cos(alow),'ro')
plt.plot(ahig,np.cos(ahig),'go')

print alow, ahig
print "sin : ", sin( Intervalo(alow,ahig) )
print "cos : ", cos( Intervalo(alow,ahig) )
# Out:
# 4.71238898038 8.05398163397
# sin :  [-1.0,1.0]
# cos :  [-0.198669330790668,1.0]

# %%
# Otro chequeo de lo mismo!
print sin(Intervalo(alow,ahig) + pi/2.0)
print cos(Intervalo(alow,ahig) )
# Out:
# [-0.198669330785868,1.0]
# [-0.198669330790668,1.0]

# %%
pi = np.pi
pi_half = pi/2.
dospi = 2.*pi
x_list = []
sin_list = []
cos_list = []
for i in range(11):
    q1 = np.random.randint(0,4)
    q2 = np.random.randint(0,4)
    print "ii= ", i, " : ", q1, q2
    if q1 > q2 :
        q2 = q2+4
    
    alow = q1*pi_half + np.random.uniform(0,pi_half)
    ahig = q2*pi_half + np.random.uniform(0,pi_half)
    x_list.append( (alow,ahig) )

    x = Intervalo(alow,ahig)
    ys = sin(x)
    yc = cos(x)
    sin_list.append(ys)
    cos_list.append(yc)
    print " x = ", x
    print "sin( x ) = ", ys
    print "cos( x ) = ", yc
    print
# Out:
# ii=  0  :  1 3
#  x =  [2.02167321376,5.28428865555]
# sin( x ) =  [-1.0,0.900065340603715]
# cos( x ) =  [-1.0,0.541230412443666]
#
# ii=  1  :  2 1
#  x =  [4.18622000059,9.2739699974]
# sin( x ) =  [-1.0,1.0]
# cos( x ) =  [-0.988650014674913,1.0]
#
# ii=  2  :  2 3
#  x =  [3.59361548567,5.18391777035]
# sin( x ) =  [-1.0,-0.436786096247738]
# cos( x ) =  [-0.899565398470096,0.45424877625798]
#
# ii=  3  :  3 0
#  x =  [5.6436558173,7.73264117753]
# sin( x ) =  [-0.596817981101197,0.992647274951378]
# cos( x ) =  [0.121042916073612,1.0]
#
# ii=  4  :  0 1
#  x =  [1.29278386832,2.80436436862]
# sin( x ) =  [0.330872767219818,1.0]
# cos( x ) =  [-0.943675374221612,0.274444966383529]
#
# ii=  5  :  1 0
#  x =  [2.38146333368,6.54964816443]
# sin( x ) =  [-1.0,0.689015175077177]
# cos( x ) =  [-1.0,1.0]
#
# ii=  6  :  3 1
#  x =  [6.10594096907,9.13788044413]
# sin( x ) =  [-0.176317756541195,1.0]
# cos( x ) =  [-0.959126424371763,1.0]
#
# ii=  7  :  1 2
#  x =  [1.67934666655,3.47377164851]
# sin( x ) =  [-0.326103678943539,0.994114194732878]
# cos( x ) =  [-1.0,-0.10833728735113]
#
# ii=  8  :  0 3
#  x =  [0.978474886198,5.68975661912]
# sin( x ) =  [-1.0,1.0]
# cos( x ) =  [-1.0,0.829028210217919]
#
# ii=  9  :  2 3
#  x =  [3.34110037492,5.34842478573]
# sin( x ) =  [-1.0,-0.198186840870707]
# cos( x ) =  [-0.980164259757358,0.594011093565376]
#
# ii=  10  :  1 0
#  x =  [2.44399171078,7.15530972547]
# sin( x ) =  [-1.0,0.765697092540096]
# cos( x ) =  [-1.0,1.0]

# %%
ii = 10
alow, ahig = x_list[ii]

xx = np.linspace( alow -1.5*pi, ahig + 1.5*pi, 1000)
plt.plot(xx,np.sin(xx),label="sin(x)")
plt.plot(xx,np.cos(xx),label="cos(x)")
plt.plot(alow,np.sin(alow),'ro')
plt.plot(ahig,np.sin(ahig),'go')
plt.plot(alow,np.cos(alow),'ro')
plt.plot(ahig,np.cos(ahig),'go')
plt.legend()

print alow, ahig
print mp.floor( (alow%dospi)/pi_half ), mp.floor( (ahig%dospi)/pi_half )
print "sin:", sin(Intervalo(alow,ahig) )
print "cos:", cos(Intervalo(alow,ahig) )
# Out:
# 2.44399171078 7.15530972547
# 1.0 0.0
# sin: [-1.0,0.765697092540096]
# cos: [-1.0,1.0]

# %%
sin(Intervalo(alow,ahig))/cos(Intervalo(alow,ahig))
# Out:
# Intervalo [mpf('-1.0'),mpf('1.0')]

# %%
ii = 10
alow, ahig = x_list[ii]
x = Intervalo(alow,ahig)

xx = np.linspace( alow -pi/2., ahig + pi/2., 1000)
plt.plot(xx,np.tan(xx),label="tan(x)")
plt.plot(alow,np.tan(alow),'ro')
plt.plot(ahig,np.tan(ahig),'go')
plt.ylim(-10, 10)
plt.legend()

print alow, ahig
print mp.floor( (alow%pi)/pi_half ), mp.floor( (ahig%pi)/pi_half )
print "sin:", sin( x )
print "cos:", cos( x )
#print "tan:", mp.tan(float(alow)), mp.tan(float(ahig))
print "sin(x)/cos(x):", sin(x)/cos(x)
print "tan(x)       :", tan(x)
# Out:
# 2.44399171078 7.15530972547
# 1.0 0.0
# sin: [-1.0,0.765697092540096]
# cos: [-1.0,1.0]
# sin(x)/cos(x): [-1.0,1.0]
# tan(x)       : [-inf,+inf]
